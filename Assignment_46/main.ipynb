# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from perceptron import Perceptron

# %% [markdown]
# # 1-Employee's salary 💵

# %% [markdown]
# - Make a linear dataset

# %%
x = np.random.normal(10,1,100)
y = x + np.random.normal(10,0.5,100)

plt.scatter(x,y)
plt.show()

# %% [markdown]
# - Split data to train and test datasets

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y,shuffle=True)
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((75,), (25,), (75,), (25,))

# %% [markdown]
# - Fit your model on the employee's salary dataset

# %%
df = Perceptron(4,5)
w,b=df.fit(x_train , y_train)
plt.scatter(x_train,y_train,color="blue")
plt.plot(x_train,x_train*w+b)

# %%
plt.scatter(x_test,y_test,color="blue")
a=df.predict(x_test)
plt.plot(x_test,a)

# %%
df.evaluate(x_test , y_test)
# Out:
# 0.009648531809723412
